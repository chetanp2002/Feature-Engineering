# %%
import numpy as np

# %%
lst_marks= [85,78,45,38,95,61,59,78,65,91,84,78,63]

# %%
minimum, Q1, median, Q3, maximum= np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (38.0, 61.0, 78.0, 84.0, 95.0)

# %%
IQR= Q3-Q1
print(IQR)
# Out:
# 23.0

# %%
lower_fence= Q1-1.5*(IQR)
higher_fence= Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# 26.5

# %%
higher_fence
# Out:
# 118.5

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks= [1,5,85,78,45,38,95,61,59,78,65,91,84,78,63,150,200]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
